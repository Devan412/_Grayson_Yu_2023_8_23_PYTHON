# %%
class Student:
    def __init__(self,name:str,ch:int,eng:int,math:int,geo:int,his:int):
        self.姓名 = name
        self.國文 = ch
        self.英文 = eng
        self.數學 = math
        self.地理 = geo
        self.歷史 = his

    def __repr__(self) -> str:
        return f'{self.姓名}的實體'

    #實體方法
    def sum(self) -> int:
        return self.國文 + self.英文 + self.數學 + self.地理 + self.歷史
#實體方法
    def average(self) -> float:
        return round(self.sum() / 5,ndigits=2)

# %%
import csv
with open("/workspaces/_Grayson_Yu_2023_8_23_PYTHON/上課用目錄/學生成績表1.csv",encoding="utf-8",newline='') as file:
    dict_reader = csv.DictReader(file)
    students = []
    for student in dict_reader:
        chinese = int(student['國文'])
        english = int(student['英文'])
        math = int(student['數學'])
        geographic = int(student['地理'])
        history = int(student['歷史'])
        student = Student(student['姓名'],
                ch=chinese,
                eng=english,
                math=math,
                geo=geographic,
                his=history)
        students.append(student)

students
# Out:
# [郭致恬的實體,
#  劉依婷的實體,
#  賴又琦的實體,
#  簡國瑋的實體,
#  陳怡珊的實體,
#  林益妏的實體,
#  陳逸華的實體,
#  柯韋成的實體,
#  游淑惠的實體,
#  鄭孟芳的實體,
#  馮淑芬的實體,
#  林世城的實體,
#  盧文啟的實體,
#  林義皓的實體,
#  蕭怡伶的實體,
#  陳倩潔的實體,
#  周芷蓁的實體,
#  羅幸娥的實體,
#  林向鈺的實體,
#  胡姿婷的實體,
#  王孝純的實體,
#  簡佳樺的實體,
#  胡淑貞的實體,
#  楊少亮的實體,
#  王品星的實體,
#  劉佳佩的實體,
#  郭淑枝的實體,
#  郭淑真的實體,
#  張慧君的實體,
#  周芷蓁的實體,
#  楊綺芬的實體,
#  劉嘉泰的實體,
#  林佳人的實體,
#  林詠斌的實體,
#  林怡偉的實體,
#  余宗儒的實體,
#  楊易政的實體,
#  吳昕婷的實體,
#  黎惠雯的實體,
#  張嘉韋的實體,
#  杜儀鳳的實體,
#  鄧淑娟的實體,
#  陳冠霞的實體,
#  崔孝憲的實體,
#  蘇凡菁的實體,
#  周家銘的實體,
#  張天亨的實體,
#  劉旭士的實體,
#  陳信念的實體,
#  李進慧的實體]

# %%
for stu in students:
    print(stu.姓名)
    print(f'總分:{stu.sum()}')
    print(f'平均:{stu.average()}')
    print("========")
# Out:
# 郭致恬
# 總分:383
# 平均:76.6
# ========
# 劉依婷
# 總分:328
# 平均:65.6
# ========
# 賴又琦
# 總分:406
# 平均:81.2
# ========
# 簡國瑋
# 總分:364
# 平均:72.8
# ========
# 陳怡珊
# 總分:425
# 平均:85.0
# ========
# 林益妏
# 總分:365
# 平均:73.0
# ========
# 陳逸華
# 總分:401
# 平均:80.2
# ========
# 柯韋成
# 總分:430
# 平均:86.0
# ========
# 游淑惠
# 總分:367
# 平均:73.4
# ========
# 鄭孟芳
# 總分:380
# 平均:76.0
# ========
# 馮淑芬
# 總分:339
# 平均:67.8
# ========
# 林世城
# 總分:358
# 平均:71.6
# ========
# 盧文啟
# 總分:419
# 平均:83.8
# ========
# 林義皓
# 總分:303
# 平均:60.6
# ========
# 蕭怡伶
# 總分:339
# 平均:67.8
# ========
# 陳倩潔
# 總分:440
# 平均:88.0
# ========
# 周芷蓁
# 總分:426
# 平均:85.2
# ========
# 羅幸娥
# 總分:330
# 平均:66.0
# ========
# 林向鈺
# 總分:394
# 平均:78.8
# ========
# 胡姿婷
# 總分:414
# 平均:82.8
# ========
# 王孝純
# 總分:408
# 平均:81.6
# ========
# 簡佳樺
# 總分:370
# 平均:74.0
# ========
# 胡淑貞
# 總分:441
# 平均:88.2
# ========
# 楊少亮
# 總分:409
# 平均:81.8
# ========
# 王品星
# 總分:422
# 平均:84.4
# ========
# 劉佳佩
# 總分:410
# 平均:82.0
# ========
# 郭淑枝
# 總分:356
# 平均:71.2
# ========
# 郭淑真
# 總分:346
# 平均:69.2
# ========
# 張慧君
# 總分:373
# 平均:74.6
# ========
# 周芷蓁
# 總分:402
# 平均:80.4
# ========
# 楊綺芬
# 總分:352
# 平均:70.4
# ========
# 劉嘉泰
# 總分:380
# 平均:76.0
# ========
# 林佳人
# 總分:415
# 平均:83.0
# ========
# 林詠斌
# 總分:404
# 平均:80.8
# ========
# 林怡偉
# 總分:334
# 平均:66.8
# ========
# 余宗儒
# 總分:387
# 平均:77.4
# ========
# 楊易政
# 總分:413
# 平均:82.6
# ========
# 吳昕婷
# 總分:294
# 平均:58.8
# ========
# 黎惠雯
# 總分:377
# 平均:75.4
# ========
# 張嘉韋
# 總分:399
# 平均:79.8
# ========
# 杜儀鳳
# 總分:420
# 平均:84.0
# ========
# 鄧淑娟
# 總分:349
# 平均:69.8
# ========
# 陳冠霞
# 總分:305
# 平均:61.0
# ========
# 崔孝憲
# 總分:423
# 平均:84.6
# ========
# 蘇凡菁
# 總分:335
# 平均:67.0
# ========
# 周家銘
# 總分:366
# 平均:73.2
# ========
# 張天亨
# 總分:422
# 平均:84.4
# ========
# 劉旭士
# 總分:391
# 平均:78.2
# ========
# 陳信念
# 總分:328
# 平均:65.6
# ========
# 李進慧
# 總分:417
# 平均:83.4
# ========
